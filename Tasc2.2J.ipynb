# %%
import matplotlib.figure
import matplotlib.pyplot
import pandas as pd
import csv
import matplotlib

fig = matplotlib.pyplot.figure()
fields = []
df = []
limits = []
ids=[]
with open("C:/Users/molot/Desktop/Data_set_new.csv", 'r') as csvfile:
    # creating a csv reader object
    csvreader = csv.reader(csvfile)

    # extracting field names through first row
    fields = next(csvreader)

    # extracting each data row one by one
    for row in csvreader:
        df.append(row)
        limits.append(int(row[3]))
        ids.append(int(row[0]))

    # get total number of rows
    print("Total no. of rows: %d" % (csvreader.line_num))

print(ids, limits)
fig, ax = matplotlib.pyplot.subplots(figsize=(15,8))
ax.bar(limits,ids)
# Out:
# Total no. of rows: 89
# [92, 66, 34, 163, 139, 114, 69, 62, 1, 135, 100, 18, 2, 16, 96, 42, 145, 22, 104, 76, 178, 121, 188, 172, 146, 26, 200, 186, 24, 199, 198, 170, 142, 138, 193, 52, 159, 150, 180, 28, 21, 173, 174, 157, 15, 130, 82, 152, 132, 124, 171, 128, 78, 167, 151, 127, 183, 131, 56, 147, 99, 93, 86, 43, 105, 165, 19, 60, 33, 108, 81, 177, 179, 129, 75, 54, 31, 65, 9, 111, 110, 103, 83, 11, 109, 58, 71, 61] [59, 48, 33, 81, 74, 64, 48, 46, 15, 73, 61, 21, 15, 20, 60, 38, 77, 24, 62, 54, 88, 67, 101, 87, 77, 28, 137, 99, 25, 137, 126, 87, 75, 73, 113, 42, 78, 78, 93, 28, 24, 87, 87, 78, 20, 71, 54, 78, 71, 69, 87, 71, 54, 86, 78, 71, 98, 71, 43, 77, 61, 60, 54, 39, 62, 85, 23, 46, 33, 63, 54, 88, 93, 71, 54, 43, 30, 48, 19, 63, 63, 62, 54, 19, 63, 44, 49, 46]
# <BarContainer object of 88 artists>
